# %% [markdown]
# # **Chapter 1**

# %% [markdown]
# #### Exercise 1
#
# Each line of code below contains an **error**. Fix the error and explain in a comment the reason for the error.

# %% [markdown]
# 1. Print('Hello World')

# %%
print('Hello world!') # using print function must use small letter
# Out:
# Hello world!

# %% [markdown]
# 2. print'Hello world!')

# %%
print('Hello world!') # the printed word must be inside the Parenthesis
# Out:
# Hello world!

# %% [markdown]
# 3. print('Hello world!'')

# %%
print('Hello world!') #bust be inside the Apostrophe like this ('Hello world')

# %% [markdown]
# #### Exercise **2**

# %% [markdown]
# What is the output of the code below? [PEW]

# %%
x = 43
x = x + 1
print(x)
#the answer is 44 becasuse x is 43 and when you add 1 to x its basically 43+1
# Out:
# 44

# %% [markdown]
# #### Exercise **3**

# %% [markdown]
# The code below contains an error. Fix the error and explain in a comment the reason for the error.

# %%
x = 43
x = X + 1
print(x)
# the code is case sensitive the variable where you add 1 the letter is in capital
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e86e654f3854> in <cell line: 2>()
#       1 x = 43
# ----> 2 x = X + 1
#       3 print(x)
#
# NameError: name 'X' is not defined
